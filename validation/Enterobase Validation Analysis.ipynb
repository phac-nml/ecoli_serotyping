# %%
import pandas as pd
import numpy as np
import os
import re

# %%
# Read info df
df = pd.read_csv('enterobase_serotype.csv').drop('Unnamed: 0', axis=1)
count = df.shape[0]
df.columns = ['genome_name', 'given_H', 'given_O', 'serotype_tag']
df.given_H='H'+df.loc[df.given_H.notnull()].given_H.astype(int).astype(str)
df.given_O='O'+df.loc[df.given_O.notnull()].given_O.astype(int).astype(str)
df2 = pd.read_csv('blacklist.csv')
df = df.merge(df2, on='genome_name', how='outer', indicator=True)
df['blacklisted'] = df._merge!='left_only'
df.drop('_merge', axis=1, inplace=True)
print('%d rows removed from blacklisted genome' %(count-df.shape[0]))
info_df = df
# Out:
# 0 rows removed from blacklisted genome

# %%
def summarize_result(result_df):
    important_cols = ['genome_name', 'given_O', 'predicted_O', 'O_info', 'given_H', 'predicted_H', 'H_info', 'wzx', 'wzy', 'wzm', 'wzt', 'fliC', 'fllA', 'flkA', 'flmA', 'flnA', 'serotype_tag']
    df = result_df[~result_df.blacklisted]
    print('all predictions(%d):' %result_df.shape[0])
    '''
    no prediction if:
        both predicted antigen are None
    '''
    s1 = (df['predicted_O'].isnull() & df['predicted_H'].isnull())
    no_df = df[s1][important_cols]
    print('%d no predictions' %no_df.shape[0])
    '''
    incorrect prediction if:
        not in 'no_df'
        at least one prediction is wrong
    '''
    s2 = (
        ((df['given_O'].notnull() & df['predicted_O'].notnull()) & (df['given_O']!=df['predicted_O'])) |
        ((df['given_H'].notnull() & df['predicted_H'].notnull()) & (df['given_H']!=df['predicted_H']))
    )
    incorrect_df = df[~s1 & s2][important_cols]
    print('%d incorrect predictions' %incorrect_df.shape[0])
    '''
    correct prediction if:
        not in 'no_df'
        not in 'incorrect_df'
        for each given serotype, the correct prediction is made
    '''
    s3 = (
        (df['given_O'].isnull() | (df['given_O']==df['predicted_O'])) &
        (df['given_H'].isnull() | (df['given_H']==df['predicted_H']))
    )
    correct_df = df[~s1 & ~s2 & s3][important_cols]
    print('%d correct predictions' %correct_df.shape[0])
    '''
    semicorrect prediction if:
        not in 'no_df'
        not in 'incorrect_df'
        not in 'correct_df'
        one correct prediction is made, no prediction for the other
    '''
    s4 = (
        (df['given_O'].isnull() | (df['given_O']==df['predicted_O'])) |
        (df['given_H'].isnull() | (df['given_H']==df['predicted_H']))
    )
    semicorrect_df = df[~s1 & ~s2 & ~s3 & s4][important_cols]
    print('%d semicorrect predictions' %semicorrect_df.shape[0])
    '''
    remaining prediction
    '''
    remaining_df = df[~s1 & ~s2 & ~s3 & ~s4]
    print('%d remaining predictions' %remaining_df.shape[0])
    
    # Summary
    correct_count = 0
    incorrect_count = 0
    given_count = 0
    # O serotype
    # get number of given serotypes
    total_s = df['given_O'].notnull()
    num_total = df[total_s].shape[0]
    given_count += num_total
    print("number of given_O serotypes is %d"
            # %num_total)
    # get number of unpredicted serotype
    unpredicted_s = total_s & df['predicted_O'].isnull()
    num_unpredicted = (df[unpredicted_s].shape[0])
    print("number of unpredicted_O serotypes is %d or %.2f%%"
            %(num_unpredicted, num_unpredicted/num_total*100))
    correct_s = total_s & ~unpredicted_s & (df['given_O']==df['predicted_O'])
    num_correct = df[correct_s].shape[0]
    correct_count += num_correct
    print("number of correctly predicted_O serotypes is %d or %.2f%%"
            %(num_correct, num_correct/num_total*100))
    incorrect_s = total_s & ~unpredicted_s & ~correct_s
    incorrect_o_df = df[incorrect_s][important_cols]
    num_incorrect = incorrect_o_df.shape[0]
    incorrect_count += num_incorrect
    print("number of incorrectly predicted_O serotypes is %d or %.2f%%"
            %(num_incorrect, num_incorrect/num_total*100))
    
    # H serotype
    # get number of given serotypes
    total_s = df['given_H'].notnull()
    num_total = (df[total_s].shape[0])
    given_count += num_total
    print("number of given_H serotypes is %d"
            # %num_total)
    # get number of unpredicted serotype
    unpredicted_s = total_s & df['predicted_H'].isnull()
    num_unpredicted = (df[unpredicted_s].shape[0])
    print("number of unpredicted_H serotypes is %d or %.2f%%"
            %(num_unpredicted, num_unpredicted/num_total*100))
    correct_s = total_s & ~unpredicted_s & (df['given_H']==df['predicted_H'])
    num_correct = df[correct_s].shape[0]
    correct_count += num_correct
    print("number of correctly predicted_H serotypes is %d or %.2f%%"
            %(num_correct, num_correct/num_total*100))
    incorrect_s = total_s & ~unpredicted_s & ~correct_s
    incorrect_h_df = df[incorrect_s][important_cols]
    num_incorrect = incorrect_h_df.shape[0]
    incorrect_count += num_incorrect
    print("number of incorrectly predicted_H serotypes is %d or %.2f%%"
            %(num_incorrect, num_incorrect/num_total*100))
    print("Overall concordance=%.2f%%(%d/%d)" %(correct_count/given_count*100, correct_count,given_count))
    print("Overall discrepancies=%.2f%%(%d/%d)" %(incorrect_count/given_count*100, incorrect_count, given_count))

    return no_df, incorrect_df, correct_df, semicorrect_df, incorrect_o_df, incorrect_h_df, result_df

# %%
# Read from result file
df = pd.read_csv('output/2017-11-09_14.20.30.622082/output.csv')
df.columns = ['genome_name', 'predicted_O', 'O_info', 'predicted_H', 'H_info', 'wzx', 'wzy', 'wzm', 'wzt', 'fliC', 'fllA', 'flkA', 'flmA', 'flnA']
df.loc[df.predicted_O=='-', 'predicted_O'] = np.nan
df.loc[df.predicted_H=='-', 'predicted_H'] = np.nan
result_df = df

# %%
# merge with info file
df = result_df
df = df.merge(info_df, on='genome_name', how='left')
df = df[['genome_name', 'given_O', 'predicted_O', 'O_info', 'given_H', 'predicted_H', 'H_info', 'wzx', 'wzy', 'wzm', 'wzt', 'fliC', 'fllA', 'flkA', 'flmA', 'flnA', 'serotype_tag', 'blacklisted']]
merge_df = df
display(merge_df)
# Out:
#           genome_name given_O predicted_O                         O_info  \
# 0     ESC_AA7875AA_AS    O157        O157                Alignment found
# 1     ESC_AA7899AA_AS    O157        O157                Alignment found
# 2     ESC_AA7929AA_AS    O157         O26                Alignment found
# 3     ESC_AA7930AA_AS    O157        O157                Alignment found
# 4     ESC_AA7942AA_AS    O157        O157                Alignment found
# 5     ESC_AA7966AA_AS    O113        O113                Alignment found
# 6     ESC_AA7970AA_AS    O157        O157                Alignment found
# 7     ESC_AA7978AA_AS    O157        O157                Alignment found
# 8     ESC_AA7989AA_AS    O157        O157                Alignment found
# 9     ESC_AA8002AA_AS    O157        O157                Alignment found
# 10    ESC_AA8009AA_AS    O157        O157                Alignment found
# 11    ESC_AA8012AA_AS    O157         O26                Alignment found
# 12    ESC_AA8026AA_AS    O157        O157                Alignment found
# 13    ESC_AA8049AA_AS    O157        O157                Alignment found
# 14    ESC_AA8076AA_AS    O157        O157                Alignment found
# 15    ESC_AA8082AA_AS    O157        O157                Alignment found
# 16    ESC_AA8101AA_AS    O157        O157                Alignment found
# 17    ESC_AA8104AA_AS    O157        O157                Alignment found
# 18    ESC_AA8156AA_AS    O157        O157                Alignment found
# 19    ESC_AA8182AA_AS    O157        O157                Alignment found
# 20    ESC_AA8212AA_AS    O157        O157                Alignment found
# 21    ESC_AA8219AA_AS    O157        O157                Alignment found
# 22    ESC_AA8228AA_AS    O103         NaN             No alignment found
# 23    ESC_AA8232AA_AS    O157        O157                Alignment found
# 24    ESC_AA8282AA_AS    O157        O157                Alignment found
# 25    ESC_AA8326AA_AS    O157        O157                Alignment found
# 26    ESC_AA8336AA_AS    O157         NaN             No alignment found
# 27    ESC_AA8374AA_AS    O157        O157                Alignment found
# 28    ESC_AA8380AA_AS    O157        O103  Lone unpaired alignment found
# 29    ESC_AA8390AA_AS    O157        O157                Alignment found
# ...               ...     ...         ...                            ...
# 5796  ESC_GA8802AA_AS    O145         NaN             No alignment found
# 5797  ESC_GA8908AA_AS    O145         NaN             No alignment found
# 5798  ESC_GA8932AA_AS    O145         NaN             No alignment found
# 5799  ESC_GA8957AA_AS     O25         NaN             No alignment found
# 5800  ESC_GA9165AA_AS    O121         NaN             No alignment found
# 5801  ESC_GA9238AA_AS      O7         NaN             No alignment found
# 5802  ESC_GA9378AA_AS     O10         NaN             No alignment found
# 5803  ESC_GA9411AA_AS     O22         NaN             No alignment found
# 5804  ESC_GA9414AA_AS     O44         NaN             No alignment found
# 5805  ESC_HA0144AA_AS    O120         NaN             No alignment found
# 5806  ESC_HA0237AA_AS    O145         NaN             No alignment found
# 5807  ESC_HA0900AA_AS    O145         NaN             No alignment found
# 5808  ESC_HA1970AA_AS     O25         NaN             No alignment found
# 5809  ESC_HA5975AA_AS     O36         NaN             No alignment found
# 5810  ESC_HA7906AA_AS     O10         NaN             No alignment found
# 5811  ESC_HA7909AA_AS     NaN         NaN             No alignment found
# 5812  ESC_HA7922AA_AS     O36         NaN             No alignment found
# 5813  ESC_HA8065AA_AS      O1         NaN             No alignment found
# 5814  ESC_HA8079AA_AS     O49         NaN             No alignment found
# 5815  ESC_HA8383AA_AS    O172         NaN             No alignment found
# 5816  ESC_HA8443AA_AS     O26         NaN             No alignment found
# 5817  ESC_HA8699AA_AS     O10         NaN             No alignment found
# 5818  ESC_HA8733AA_AS    O145         NaN             No alignment found
# 5819  ESC_HA8762AA_AS     O36         NaN             No alignment found
# 5820  ESC_HA9973AA_AS     NaN         NaN             No alignment found
# 5821  ESC_IA6411AA_AS    O145         NaN             No alignment found
# 5822  ESC_IA6426AA_AS    O145         NaN             No alignment found
# 5823  ESC_IA6978AA_AS    O145         NaN             No alignment found
# 5824  ESC_IA6985AA_AS    O145         NaN             No alignment found
# 5825  ESC_PA2018AA_AS    O157         NaN             No alignment found
#
#      given_H predicted_H              H_info   wzx   wzy wzm wzt  fliC fllA  \
# 0        NaN          H7     Alignment found  True  True   -   -  True    -
# 1        NaN          H7     Alignment found  True  True   -   -  True    -
# 2        NaN         H11     Alignment found  True  True   -   -  True    -
# 3        NaN          H7     Alignment found  True  True   -   -  True    -
# 4        NaN          H7     Alignment found  True  True   -   -  True    -
# 5        H21         H21     Alignment found  True  True   -   -  True    -
# 6        NaN          H7     Alignment found  True  True   -   -  True    -
# 7        NaN          H7     Alignment found  True  True   -   -  True    -
# 8        NaN          H7     Alignment found  True  True   -   -  True    -
# 9        NaN          H7     Alignment found  True  True   -   -  True    -
# 10       NaN          H7     Alignment found  True  True   -   -  True    -
# 11       NaN         H11     Alignment found  True  True   -   -  True    -
# 12       NaN          H7     Alignment found  True  True   -   -  True    -
# 13       NaN          H7     Alignment found  True  True   -   -  True    -
# 14       NaN          H7     Alignment found  True  True   -   -  True    -
# 15       NaN          H7     Alignment found  True  True   -   -  True    -
# 16        H7          H7     Alignment found  True  True   -   -  True    -
# 17       NaN          H7     Alignment found  True  True   -   -  True    -
# 18       NaN          H7     Alignment found  True  True   -   -  True    -
# 19       NaN          H7     Alignment found  True  True   -   -  True    -
# 20       NaN          H7     Alignment found  True  True   -   -  True    -
# 21       NaN          H7     Alignment found  True  True   -   -  True    -
# 22       NaN         H25     Alignment found     -     -   -   -  True    -
# 23        H7          H7     Alignment found  True  True   -   -  True    -
# 24       NaN          H7     Alignment found  True  True   -   -  True    -
# 25       NaN          H7     Alignment found  True  True   -   -  True    -
# 26        H7          H7     Alignment found     -     -   -   -  True    -
# 27       NaN          H7     Alignment found  True  True   -   -  True    -
# 28       NaN          H2     Alignment found  True     -   -   -  True    -
# 29       NaN          H7     Alignment found  True  True   -   -  True    -
# ...      ...         ...                 ...   ...   ...  ..  ..   ...  ...
# 5796     H28         NaN  No alignment found     -     -   -   -     -    -
# 5797     H28         NaN  No alignment found     -     -   -   -     -    -
# 5798     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5799      H6         NaN  No alignment found     -     -   -   -     -    -
# 5800     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5801     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5802     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5803     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5804     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5805      H7         NaN  No alignment found     -     -   -   -     -    -
# 5806     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5807     H28         NaN  No alignment found     -     -   -   -     -    -
# 5808      H4         NaN  No alignment found     -     -   -   -     -    -
# 5809     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5810     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5811     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5812     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5813     H20         NaN  No alignment found     -     -   -   -     -    -
# 5814     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5815     H28         NaN  No alignment found     -     -   -   -     -    -
# 5816     H32         NaN  No alignment found     -     -   -   -     -    -
# 5817     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5818     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5819     NaN         NaN  No alignment found     -     -   -   -     -    -
# 5820     H14         NaN  No alignment found     -     -   -   -     -    -
# 5821     H28         NaN  No alignment found     -     -   -   -     -    -
# 5822     H28         NaN  No alignment found     -     -   -   -     -    -
# 5823     H28         NaN  No alignment found     -     -   -   -     -    -
# 5824     H28         NaN  No alignment found     -     -   -   -     -    -
# 5825     NaN         NaN  No alignment found     -     -   -   -     -    -
#
#      flkA flmA flnA serotype_tag  blacklisted
# 0       -    -    -         O157        False
# 1       -    -    -         O157        False
# 2       -    -    -         O157         True
# 3       -    -    -         O157        False
# 4       -    -    -         O157        False
# 5       -    -    -     O113:H21        False
# 6       -    -    -         O157        False
# 7       -    -    -         O157        False
# 8       -    -    -         O157        False
# 9       -    -    -         O157        False
# 10      -    -    -         O157        False
# 11      -    -    -         O157         True
# 12      -    -    -         O157        False
# 13      -    -    -         O157        False
# 14      -    -    -         O157        False
# 15      -    -    -         O157        False
# 16      -    -    -      O157:H7        False
# 17      -    -    -         O157        False
# 18      -    -    -         O157        False
# 19      -    -    -         O157        False
# 20      -    -    -         O157        False
# 21      -    -    -         O157        False
# 22      -    -    -         O103        False
# 23      -    -    -      O157:H7        False
# 24      -    -    -         O157        False
# 25      -    -    -         O157        False
# 26      -    -    -      O157:H7        False
# 27      -    -    -         O157        False
# 28      -    -    -         O157         True
# 29      -    -    -         O157        False
# ...   ...  ...  ...          ...          ...
# 5796    -    -    -     O145:H28        False
# 5797    -    -    -     O145:H28        False
# 5798    -    -    -         O145        False
# 5799    -    -    -       O25:H6        False
# 5800    -    -    -         O121        False
# 5801    -    -    -           O7        False
# 5802    -    -    -          O10        False
# 5803    -    -    -          O22        False
# 5804    -    -    -          O44        False
# 5805    -    -    -      O120:H7        False
# 5806    -    -    -         O145        False
# 5807    -    -    -     O145:H28        False
# 5808    -    -    -      O25B:H4        False
# 5809    -    -    -          O36        False
# 5810    -    -    -          O10        False
# 5811    -    -    -         Ox25        False
# 5812    -    -    -          O36        False
# 5813    -    -    -       O1:H20        False
# 5814    -    -    -          O49        False
# 5815    -    -    -     O172:H28        False
# 5816    -    -    -      O26:H32        False
# 5817    -    -    -          O10        False
# 5818    -    -    -         O145        False
# 5819    -    -    -          O36        False
# 5820    -    -    -       O.:H14        False
# 5821    -    -    -     O145:H28        False
# 5822    -    -    -     O145:H28        False
# 5823    -    -    -     O145:H28        False
# 5824    -    -    -     O145:H28        False
# 5825    -    -    -         O157        False
#
# [5826 rows x 18 columns]

# %%
results = summarize_result(merge_df)
# Out:
# all predictions(5826):
# 39 no predictions
# 280 incorrect predictions
# 4278 correct predictions
# 744 semicorrect predictions
# 0 remaining predictions
# number of given_O serotypes is 5209
# number of unpredicted_O serotypes is 821 or 15.76%
# number of correctly predicted_O serotypes is 4227 or 81.15%
# number of incorrectly predicted_O serotypes is 161 or 3.09%
# number of given_H serotypes is 2566
# number of unpredicted_H serotypes is 40 or 1.56%
# number of correctly predicted_H serotypes is 2384 or 92.91%
# number of incorrectly predicted_H serotypes is 142 or 5.53%
# Overall concordance=85.03%(6611/7775)
# Overall discrepancies=3.90%(303/7775)

# %%
results[-1].to_csv('enterobase_result.csv')

# %%
def result_to_summary(df):
    h_interested_cols = ['genome_name', 'given_H', 'predicted_H', 'H_info', 'fliC', 'fllA', 'flkA', 'flmA', 'flnA']
    o_interested_cols = ['genome_name', 'given_O', 'predicted_O', 'O_info', 'wzx', 'wzy', 'wzm', 'wzt']
    # split into two dfs
    def rename_antigen_cols(df, antigen):
        df = df.rename(columns={
            'given_'+antigen: 'given',
            'predicted_'+antigen:'predicted',
            antigen+'_info':'info'})
        df = df[df['given'].notnull() | df['predicted'].notnull()]
        df = df[df['given'] != df['predicted']]
        return df
    h_df = rename_antigen_cols(df[h_interested_cols], 'H')
    o_df = rename_antigen_cols(df[o_interested_cols], 'O')
    df = h_df.append(o_df, ignore_index=True)
    interested_cols = ['genome_name', 'given', 'predicted', 'info']
    df = df[interested_cols]
    df['explanation'] = np.nan
    df.loc[(df['info']=='No alignment found') & df.explanation.isnull(), 'explanation'] = 'No matching alignment'
    df.loc[df.given.isnull() & df.explanation.isnull(), 'explanation'] = 'Insufficient serotype info'
    df.loc[(df.genome_name=='GCA_000632575.1_Ec2009C-4747') & df.explanation.isnull(), 'explanation'] = 'Mislabelled, see "image/gen_tre1.png"'
    df.loc[(df.genome_name=='GCA_000619345.1_Ec2009C-3292') & df.explanation.isnull(), 'explanation'] = 'Mislabelled, see "image/gen_tre2.png"'
    df.loc[(df.genome_name=='GCA_000617165.2_Ec02-3404') & df.explanation.isnull(), 'explanation'] = 'identified as non-ecoli by reference marker alignment'
    df.loc[df['info'].isnull() & df.explanation.isnull(), 'explanation'] = 'File system error'
    df.loc[df.explanation.isnull(), 'explanation'] = 'Not sure'
    df = df.drop(['info'], axis=1)
    df.to_csv('enterobase_result_summary.csv', na_rep='N/A')
    return df
df = result_to_summary(results[-1])
df[df.explanation=='Not sure']
# Out:
#           genome_name given predicted explanation
# 99    ESC_BA0018AA_AS    H7       H21    Not sure
# 291   ESC_BA4596AA_AS    H1       H12    Not sure
# 357   ESC_BA5875AA_AS    H7       H52    Not sure
# 831   ESC_CA6510AA_AS   H19        H2    Not sure
# 887   ESC_FA6795AA_AS   H54       H11    Not sure
# 888   ESC_FA6803AA_AS   H54       H27    Not sure
# 889   ESC_FA6805AA_AS   H54       H27    Not sure
# 890   ESC_FA6818AA_AS   H36       H27    Not sure
# 893   ESC_FA6849AA_AS   H36       H27    Not sure
# 894   ESC_FA6863AA_AS   H44        H4    Not sure
# 895   ESC_FA6867AA_AS   H55       H25    Not sure
# 898   ESC_FA6893AA_AS   H24       H49    Not sure
# 899   ESC_FA6900AA_AS   H18       H19    Not sure
# 959   ESC_FA8272AA_AS    H7       H30    Not sure
# 1194  ESC_GA6660AA_AS    H9       H21    Not sure
# 1195  ESC_GA6663AA_AS    H8       H10    Not sure
# 1196  ESC_GA6665AA_AS   H11       H21    Not sure
# 1198  ESC_GA6669AA_AS   H11        H6    Not sure
# 1224  ESC_GA6824AA_AS   H11       H21    Not sure
# 1226  ESC_GA6833AA_AS   H11       H21    Not sure
# 1232  ESC_GA6849AA_AS   H11       H21    Not sure
# 1233  ESC_GA6856AA_AS    H9       H20    Not sure
# 1234  ESC_GA6857AA_AS    H9       H20    Not sure
# 1235  ESC_GA6861AA_AS   H14       H23    Not sure
# 1236  ESC_GA6862AA_AS   H14       H23    Not sure
# 1237  ESC_GA6868AA_AS   H14       H23    Not sure
# 1238  ESC_GA6869AA_AS   H21       H14    Not sure
# 1239  ESC_GA6871AA_AS   H10       H25    Not sure
# 1240  ESC_GA6877AA_AS    H8       H25    Not sure
# 1241  ESC_GA6881AA_AS   H19       H27    Not sure
# ...               ...   ...       ...         ...
# 4571  ESC_LA5730AA_AS  O125        O2    Not sure
# 4572  ESC_LA5731AA_AS   O77       NaN    Not sure
# 4575  ESC_LA5758AA_AS   O45      O115    Not sure
# 4576  ESC_LA5766AA_AS    O2      O166    Not sure
# 4577  ESC_LA5767AA_AS  O141        O8    Not sure
# 4579  ESC_LA5770AA_AS    O3      O117    Not sure
# 4580  ESC_LA5771AA_AS   O85      O131    Not sure
# 4581  ESC_LA5775AA_AS  O143       O15    Not sure
# 4582  ESC_LA5787AA_AS  O153       O12    Not sure
# 4584  ESC_LA5849AA_AS  O110       O29    Not sure
# 4585  ESC_LA5850AA_AS   O23      O180    Not sure
# 4586  ESC_LA5875AA_AS   O13       O19    Not sure
# 4588  ESC_LA5878AA_AS   O88      O147    Not sure
# 4589  ESC_LA5881AA_AS   O19       O49    Not sure
# 4590  ESC_LA5891AA_AS    O7      O153    Not sure
# 4592  ESC_LA5905AA_AS  O109        O8    Not sure
# 4593  ESC_LA5907AA_AS  O149       O74    Not sure
# 4594  ESC_LA5911AA_AS   O10      O112    Not sure
# 4595  ESC_LA5912AA_AS   O91       O21    Not sure
# 4596  ESC_LA5913AA_AS    O9       O75    Not sure
# 4597  ESC_LA5914AA_AS    O4       O91    Not sure
# 4598  ESC_LA5915AA_AS   O15      O109    Not sure
# 4617  ESC_MA1495AA_AS  O103        O8    Not sure
# 4632  ESC_NA8318AA_AS  O103      O126    Not sure
# 4633  ESC_NA8995AA_AS   O68       O18    Not sure
# 4645  ESC_NA9545AA_AS  O103      O163    Not sure
# 4655  ESC_PA1482AA_AS  O157       O89    Not sure
# 4659  ESC_PA1999AA_AS  O157        O8    Not sure
# 4660  ESC_PA2007AA_AS  O157       O75    Not sure
# 4663  ESC_PA2044AA_AS  O157        O8    Not sure
#
# [868 rows x 4 columns]
