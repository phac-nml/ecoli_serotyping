# %%
import pandas as pd
import numpy as np
import os
import re

# %%
# Function definitions
def get_diff_row(df1, df2, on):
    df = df1.merge(df2, on=on, how='outer', indicator=True)
    return (df[df._merge!='both'])
def summarize_result(result_df):
    df = result_df.copy()
    important_cols = ['genome_name', 'given_O', 'predicted_O', 'O_info', 'given_H', 'predicted_H', 'H_info', 'serotype_tag']
    print('all predictions(%d):' %result_df.shape[0])
    '''
    no prediction if:
        both predicted antigen are None
    '''
    s1 = (df['predicted_O'].isnull() & df['predicted_H'].isnull())
    no_df = df[s1][important_cols]
    print('%d no predictions' %no_df.shape[0])
    '''
    incorrect prediction if:
        not in 'no_df'
        at least one prediction is wrong
    '''
    s2 = (
        ((df['given_O'].notnull() & df['predicted_O'].notnull()) & (df['given_O']!=df['predicted_O'])) |
        ((df['given_H'].notnull() & df['predicted_H'].notnull()) & (df['given_H']!=df['predicted_H']))
    )
    incorrect_df = df[~s1 & s2][important_cols]
    print('%d incorrect predictions' %incorrect_df.shape[0])
    '''
    correct prediction if:
        not in 'no_df'
        not in 'incorrect_df'
        for each given serotype, the correct prediction is made
    '''
    s3 = (
        (df['given_O'].isnull() | (df['given_O']==df['predicted_O'])) &
        (df['given_H'].isnull() | (df['given_H']==df['predicted_H']))
    )
    correct_df = df[~s1 & ~s2 & s3][important_cols]
    print('%d correct predictions' %correct_df.shape[0])
    '''
    semicorrect prediction if:
        not in 'no_df'
        not in 'incorrect_df'
        not in 'correct_df'
        one correct prediction is made, no prediction for the other
    '''
    s4 = (
        (df['given_O'].isnull() | (df['given_O']==df['predicted_O'])) |
        (df['given_H'].isnull() | (df['given_H']==df['predicted_H']))
    )
    semicorrect_df = df[~s1 & ~s2 & ~s3 & s4][important_cols]
    print('%d semicorrect predictions' %semicorrect_df.shape[0])
    '''
    remaining prediction
    '''
    remaining_df = df[~s1 & ~s2 & ~s3 & ~s4]
    print('%d remaining predictions' %remaining_df.shape[0])
    
    # Summary
    correct_count = 0
    incorrect_count = 0
    given_count = 0
    # O serotype
    # get number of given serotypes
    total_s = df['given_O'].notnull()
    num_total = df[total_s].shape[0]
    given_count += num_total
    print("number of given_O serotypes is %d"
            # %num_total)
    # get number of unpredicted serotype
    unpredicted_s = total_s & df['predicted_O'].isnull()
    num_unpredicted = (df[unpredicted_s].shape[0])
    print("number of unpredicted_O serotypes is %d or %.2f%%"
            %(num_unpredicted, num_unpredicted/num_total*100))
    correct_s = total_s & ~unpredicted_s & (df['given_O']==df['predicted_O'])
    num_correct = df[correct_s].shape[0]
    correct_count += num_correct
    print("number of correctly predicted_O serotypes is %d or %.2f%%"
            %(num_correct, num_correct/num_total*100))
    incorrect_s = total_s & ~unpredicted_s & ~correct_s
    incorrect_o_df = df[incorrect_s][important_cols]
    num_incorrect = incorrect_o_df.shape[0]
    incorrect_count += num_incorrect
    print("number of incorrectly predicted_O serotypes is %d or %.2f%%"
            %(num_incorrect, num_incorrect/num_total*100))
    
    # H serotype
    # get number of given serotypes
    total_s = df['given_H'].notnull()
    num_total = (df[total_s].shape[0])
    given_count += num_total
    print("number of given_H serotypes is %d"
            # %num_total)
    # get number of unpredicted serotype
    unpredicted_s = total_s & df['predicted_H'].isnull()
    num_unpredicted = (df[unpredicted_s].shape[0])
    print("number of unpredicted_H serotypes is %d or %.2f%%"
            %(num_unpredicted, num_unpredicted/num_total*100))
    correct_s = total_s & ~unpredicted_s & (df['given_H']==df['predicted_H'])
    num_correct = df[correct_s].shape[0]
    correct_count += num_correct
    print("number of correctly predicted_H serotypes is %d or %.2f%%"
            %(num_correct, num_correct/num_total*100))
    incorrect_s = total_s & ~unpredicted_s & ~correct_s
    incorrect_h_df = df[incorrect_s][important_cols]
    num_incorrect = incorrect_h_df.shape[0]
    incorrect_count += num_incorrect
    print("number of incorrectly predicted_H serotypes is %d or %.2f%%"
            %(num_incorrect, num_incorrect/num_total*100))
    print("Overall concordance=%.2f%%(%d/%d)" %(correct_count/given_count*100, correct_count,given_count))
    print("Overall discrepancies=%.2f%%(%d/%d)" %(incorrect_count/given_count*100, incorrect_count, given_count))

    return no_df, incorrect_df, correct_df, semicorrect_df, incorrect_o_df, incorrect_h_df, result_df

def remove_blacklist_genomes(df):
    start_count = df.shape[0]
    print('Start with %d rows' %(start_count))
    df = df[~df.blacklisted]
    print('%d rows removed for blacklisted genome' %(start_count-df.shape[0]))
    print('End with %d rows' %(df.shape[0]))
    return df

def mark_blacklist_genomes(df, blacklist_file):
    blacklist_df = pd.read_csv(blacklist_file)
    df = df.merge(blacklist_df, on='genome_name', how='outer', indicator=True)
    df['blacklisted'] = df._merge!='left_only'
    df.drop('_merge', axis=1, inplace=True)
    return df

def read_info_df(file):
    # Read info df
    df = pd.read_csv(file).drop('Unnamed: 0', axis=1)
    df.columns = ['genome_name', 'given_H', 'given_O', 'serotype_tag']
    df.given_H='H'+df.loc[df.given_H.notnull()].given_H.astype(int).astype(str)
    df.given_O='O'+df.loc[df.given_O.notnull()].given_O.astype(int).astype(str)
    df = mark_blacklist_genomes(df, 'blacklist.csv')
    df = remove_blacklist_genomes(df)
    return df

def read_output_file(file):
    # Read from result file
    df = pd.read_csv(file)
    df = df[['index', 'O_prediction', 'O_info', 'H_prediction', 'H_info']]
    df.columns = ['genome_name', 'predicted_O', 'O_info', 'predicted_H', 'H_info']
    df.loc[df.predicted_O=='-', 'predicted_O'] = np.nan
    df.loc[df.predicted_H=='-', 'predicted_H'] = np.nan
    return df

def create_merge_df(info_file, output_file):
    # merge with info file
    df = read_output_file(output_file)
    df2 = read_info_df(info_file)
    df = df.merge(df2, on='genome_name', how='inner')
    df = df[['genome_name', 'given_O', 'predicted_O', 'O_info', 'given_H', 'predicted_H', 'H_info', 'serotype_tag', 'blacklisted']]
    return df

# %%
merge_df = create_merge_df('enterobase_serotype.csv', 'output/enterobase/output.csv')
results = summarize_result(merge_df)
get_diff_row(read_info_df('enterobase_serotype.csv'), merge_df, 'genome_name')
merge_df
# Out:
# Start with 5844 rows
# 489 rows removed for blacklisted genome
# End with 5355 rows
# all predictions(5355):
# 44 no predictions
# 282 incorrect predictions
# 4283 correct predictions
# 746 semicorrect predictions
# 0 remaining predictions
# number of given_O serotypes is 5223
# number of unpredicted_O serotypes is 827 or 15.83%
# number of correctly predicted_O serotypes is 4233 or 81.05%
# number of incorrectly predicted_O serotypes is 163 or 3.12%
# number of given_H serotypes is 2570
# number of unpredicted_H serotypes is 44 or 1.71%
# number of correctly predicted_H serotypes is 2384 or 92.76%
# number of incorrectly predicted_H serotypes is 142 or 5.53%
# Overall concordance=84.91%(6617/7793)
# Overall discrepancies=3.91%(305/7793)
# Start with 5844 rows
# 489 rows removed for blacklisted genome
# End with 5355 rows
#           genome_name given_O predicted_O              O_info given_H  \
# 0     ESC_AA7875AA_AS    O157        O157     Alignment found     NaN
# 1     ESC_AA7899AA_AS    O157        O157     Alignment found     NaN
# 2     ESC_AA7930AA_AS    O157        O157     Alignment found     NaN
# 3     ESC_AA7942AA_AS    O157        O157     Alignment found     NaN
# 4     ESC_AA7966AA_AS    O113        O113     Alignment found     H21
# 5     ESC_AA7970AA_AS    O157        O157     Alignment found     NaN
# 6     ESC_AA7978AA_AS    O157        O157     Alignment found     NaN
# 7     ESC_AA7989AA_AS    O157        O157     Alignment found     NaN
# 8     ESC_AA8002AA_AS    O157        O157     Alignment found     NaN
# 9     ESC_AA8009AA_AS    O157        O157     Alignment found     NaN
# 10    ESC_AA8026AA_AS    O157        O157     Alignment found     NaN
# 11    ESC_AA8049AA_AS    O157        O157     Alignment found     NaN
# 12    ESC_AA8076AA_AS    O157        O157     Alignment found     NaN
# 13    ESC_AA8082AA_AS    O157        O157     Alignment found     NaN
# 14    ESC_AA8101AA_AS    O157        O157     Alignment found      H7
# 15    ESC_AA8104AA_AS    O157        O157     Alignment found     NaN
# 16    ESC_AA8156AA_AS    O157        O157     Alignment found     NaN
# 17    ESC_AA8182AA_AS    O157        O157     Alignment found     NaN
# 18    ESC_AA8212AA_AS    O157        O157     Alignment found     NaN
# 19    ESC_AA8219AA_AS    O157        O157     Alignment found     NaN
# 20    ESC_AA8228AA_AS    O103         NaN  No alignment found     NaN
# 21    ESC_AA8232AA_AS    O157        O157     Alignment found      H7
# 22    ESC_AA8282AA_AS    O157        O157     Alignment found     NaN
# 23    ESC_AA8326AA_AS    O157        O157     Alignment found     NaN
# 24    ESC_AA8336AA_AS    O157         NaN  No alignment found      H7
# 25    ESC_AA8374AA_AS    O157        O157     Alignment found     NaN
# 26    ESC_AA8390AA_AS    O157        O157     Alignment found     NaN
# 27    ESC_AA8414AA_AS    O157        O157     Alignment found     NaN
# 28    ESC_AA8451AA_AS    O157        O157     Alignment found     NaN
# 29    ESC_AA8457AA_AS    O157        O157     Alignment found     NaN
# ...               ...     ...         ...                 ...     ...
# 5325  ESC_GA8932AA_AS    O145         NaN  No alignment found     NaN
# 5326  ESC_GA8957AA_AS     O25         NaN  No alignment found      H6
# 5327  ESC_GA9074AA_AS    O136         NaN  No alignment found      H7
# 5328  ESC_GA9165AA_AS    O121         NaN  No alignment found     NaN
# 5329  ESC_GA9238AA_AS      O7         NaN  No alignment found     NaN
# 5330  ESC_GA9378AA_AS     O10         NaN  No alignment found     NaN
# 5331  ESC_GA9411AA_AS     O22         NaN  No alignment found     NaN
# 5332  ESC_GA9414AA_AS     O44         NaN  No alignment found     NaN
# 5333  ESC_HA0144AA_AS    O120         NaN  No alignment found      H7
# 5334  ESC_HA0237AA_AS    O145         NaN  No alignment found     NaN
# 5335  ESC_HA0900AA_AS    O145         NaN  No alignment found     H28
# 5336  ESC_HA1970AA_AS     O25         NaN  No alignment found      H4
# 5337  ESC_HA5975AA_AS     O36         NaN  No alignment found     NaN
# 5338  ESC_HA7906AA_AS     O10         NaN  No alignment found     NaN
# 5339  ESC_HA7909AA_AS     NaN         NaN  No alignment found     NaN
# 5340  ESC_HA7922AA_AS     O36         NaN  No alignment found     NaN
# 5341  ESC_HA8065AA_AS      O1         NaN  No alignment found     H20
# 5342  ESC_HA8079AA_AS     O49         NaN  No alignment found     NaN
# 5343  ESC_HA8383AA_AS    O172         NaN  No alignment found     H28
# 5344  ESC_HA8443AA_AS     O26         NaN  No alignment found     H32
# 5345  ESC_HA8509AA_AS      O5         NaN  No alignment found      H5
# 5346  ESC_HA8699AA_AS     O10         NaN  No alignment found     NaN
# 5347  ESC_HA8733AA_AS    O145         NaN  No alignment found     NaN
# 5348  ESC_HA8762AA_AS     O36         NaN  No alignment found     NaN
# 5349  ESC_HA9973AA_AS     NaN         NaN  No alignment found     H14
# 5350  ESC_IA6411AA_AS    O145         NaN  No alignment found     H28
# 5351  ESC_IA6426AA_AS    O145         NaN  No alignment found     H28
# 5352  ESC_IA6978AA_AS    O145         NaN  No alignment found     H28
# 5353  ESC_IA6985AA_AS    O145         NaN  No alignment found     H28
# 5354  ESC_PA2018AA_AS    O157         NaN  No alignment found     NaN
#
#      predicted_H              H_info serotype_tag  blacklisted
# 0             H7     Alignment found         O157        False
# 1             H7     Alignment found         O157        False
# 2             H7     Alignment found         O157        False
# 3             H7     Alignment found         O157        False
# 4            H21     Alignment found     O113:H21        False
# 5             H7     Alignment found         O157        False
# 6             H7     Alignment found         O157        False
# 7             H7     Alignment found         O157        False
# 8             H7     Alignment found         O157        False
# 9             H7     Alignment found         O157        False
# 10            H7     Alignment found         O157        False
# 11            H7     Alignment found         O157        False
# 12            H7     Alignment found         O157        False
# 13            H7     Alignment found         O157        False
# 14            H7     Alignment found      O157:H7        False
# 15            H7     Alignment found         O157        False
# 16            H7     Alignment found         O157        False
# 17            H7     Alignment found         O157        False
# 18            H7     Alignment found         O157        False
# 19            H7     Alignment found         O157        False
# 20           H25     Alignment found         O103        False
# 21            H7     Alignment found      O157:H7        False
# 22            H7     Alignment found         O157        False
# 23            H7     Alignment found         O157        False
# 24            H7     Alignment found      O157:H7        False
# 25            H7     Alignment found         O157        False
# 26            H7     Alignment found         O157        False
# 27            H7     Alignment found         O157        False
# 28            H7     Alignment found         O157        False
# 29            H7     Alignment found         O157        False
# ...          ...                 ...          ...          ...
# 5325         NaN  No alignment found         O145        False
# 5326         NaN  No alignment found       O25:H6        False
# 5327         NaN  No alignment found      O136:H7        False
# 5328         NaN  No alignment found         O121        False
# 5329         NaN  No alignment found           O7        False
# 5330         NaN  No alignment found          O10        False
# 5331         NaN  No alignment found          O22        False
# 5332         NaN  No alignment found          O44        False
# 5333         NaN  No alignment found      O120:H7        False
# 5334         NaN  No alignment found         O145        False
# 5335         NaN  No alignment found     O145:H28        False
# 5336         NaN  No alignment found      O25B:H4        False
# 5337         NaN  No alignment found          O36        False
# 5338         NaN  No alignment found          O10        False
# 5339         NaN  No alignment found         Ox25        False
# 5340         NaN  No alignment found          O36        False
# 5341         NaN  No alignment found       O1:H20        False
# 5342         NaN  No alignment found          O49        False
# 5343         NaN  No alignment found     O172:H28        False
# 5344         NaN  No alignment found      O26:H32        False
# 5345         NaN  No alignment found        O5:H5        False
# 5346         NaN  No alignment found          O10        False
# 5347         NaN  No alignment found         O145        False
# 5348         NaN  No alignment found          O36        False
# 5349         NaN  No alignment found       O.:H14        False
# 5350         NaN  No alignment found     O145:H28        False
# 5351         NaN  No alignment found     O145:H28        False
# 5352         NaN  No alignment found     O145:H28        False
# 5353         NaN  No alignment found     O145:H28        False
# 5354         NaN  No alignment found         O157        False
#
# [5355 rows x 9 columns]

# %%
print(merge_df.shape)
results = summarize_result(merge_df)
# Out:
# (5355, 9)
# all predictions(5355):
# 44 no predictions
# 282 incorrect predictions
# 4283 correct predictions
# 746 semicorrect predictions
# 0 remaining predictions
# number of given_O serotypes is 5223
# number of unpredicted_O serotypes is 827 or 15.83%
# number of correctly predicted_O serotypes is 4233 or 81.05%
# number of incorrectly predicted_O serotypes is 163 or 3.12%
# number of given_H serotypes is 2570
# number of unpredicted_H serotypes is 44 or 1.71%
# number of correctly predicted_H serotypes is 2384 or 92.76%
# number of incorrectly predicted_H serotypes is 142 or 5.53%
# Overall concordance=84.91%(6617/7793)
# Overall discrepancies=3.91%(305/7793)

# %%
def result_to_summary(result_df):
    # split into two dfs
    def rename_antigen_cols(df, antigen):
        df = df.rename(columns={
            'given_'+antigen: 'given',
            'predicted_'+antigen:'predicted',
            antigen+'_info':'info'})
        df = df[df['given'].notnull()]
        df = df[df['given'] != df['predicted']]
        return df
    writer = pd.ExcelWriter('enterobase_summary.xlsx')
    summary_dfs = []
    for antigen in ['O', 'H']:
        df = result_df.copy()
        interested_cols = ['genome_name', 'given_'+antigen, 'predicted_'+antigen, antigen+'_info']
        df = rename_antigen_cols(df[interested_cols], antigen)
        print(df.shape)
        interested_cols = ['genome_name', 'given', 'predicted', 'info']
        df = df[interested_cols]
        df['explanation'] = np.nan
        df.loc[(df['info']=='No alignment found') & df.explanation.isnull(), 'explanation'] = 'No matching alignment'
        df.loc[df.given.isnull() & df.explanation.isnull(), 'explanation'] = 'Insufficient serotype info'
        df.loc[(df.genome_name=='GCA_000617165.2_Ec02-3404') & df.explanation.isnull(), 'explanation'] = 'identified as non-ecoli by reference marker alignment'
        df.loc[df['info'].isnull() & df.explanation.isnull(), 'explanation'] = 'File system error'
        df.loc[df.explanation.isnull(), 'explanation'] = 'Not sure'
        df = df.drop(['info'], axis=1)
        df.reset_index(inplace=True, drop=True)
        df.to_excel(writer,'%s serotype'%antigen, na_rep='-')
        summary_dfs.append(df)
    writer.save()
    return summary_dfs
df = result_to_summary(results[-1])[0]
# Out:
# (990, 4)
# (186, 4)
#          genome_name given predicted            explanation
# 0    ESC_AA8228AA_AS  O103       NaN  No matching alignment
# 1    ESC_AA8336AA_AS  O157       NaN  No matching alignment
# 2    ESC_AA8870AA_AS  O103       NaN  No matching alignment
# 3    ESC_AA9454AA_AS   O26       NaN  No matching alignment
# 4    ESC_AA9488AA_AS  O157       NaN  No matching alignment
# 5    ESC_AA9657AA_AS  O103       NaN  No matching alignment
# 6    ESC_AA9661AA_AS  O157      O121               Not sure
# 7    ESC_AA9677AA_AS  O157       NaN  No matching alignment
# 8    ESC_AA9748AA_AS  O157       NaN  No matching alignment
# 9    ESC_BA0283AA_AS  O157      O146               Not sure
# 10   ESC_BA0292AA_AS  O157      O177               Not sure
# 11   ESC_BA0690AA_AS  O157       NaN  No matching alignment
# 12   ESC_BA0829AA_AS  O157       NaN  No matching alignment
# 13   ESC_BA0981AA_AS  O157       NaN  No matching alignment
# 14   ESC_BA1201AA_AS  O157       NaN  No matching alignment
# 15   ESC_BA1526AA_AS  O157        O6               Not sure
# 16   ESC_BA1890AA_AS  O157       O49               Not sure
# 17   ESC_BA1983AA_AS  O103       NaN  No matching alignment
# 18   ESC_BA2115AA_AS  O157       NaN  No matching alignment
# 19   ESC_BA2140AA_AS  O157       NaN  No matching alignment
# 20   ESC_BA2671AA_AS  O157       NaN  No matching alignment
# 21   ESC_BA2672AA_AS  O157      O126               Not sure
# 22   ESC_BA3234AA_AS  O157       NaN  No matching alignment
# 23   ESC_BA3539AA_AS  O111       NaN  No matching alignment
# 24   ESC_BA4083AA_AS  O157      O159               Not sure
# 25   ESC_BA4097AA_AS  O111       NaN  No matching alignment
# 26   ESC_BA4207AA_AS  O157       NaN  No matching alignment
# 27   ESC_BA4383AA_AS  O157       NaN  No matching alignment
# 28   ESC_BA4490AA_AS  O157       NaN  No matching alignment
# 29   ESC_BA4565AA_AS   O26       NaN  No matching alignment
# ..               ...   ...       ...                    ...
# 960  ESC_GA8887AA_AS   O61       NaN  No matching alignment
# 961  ESC_GA8908AA_AS  O145       NaN  No matching alignment
# 962  ESC_GA8932AA_AS  O145       NaN  No matching alignment
# 963  ESC_GA8957AA_AS   O25       NaN  No matching alignment
# 964  ESC_GA9074AA_AS  O136       NaN  No matching alignment
# 965  ESC_GA9165AA_AS  O121       NaN  No matching alignment
# 966  ESC_GA9238AA_AS    O7       NaN  No matching alignment
# 967  ESC_GA9378AA_AS   O10       NaN  No matching alignment
# 968  ESC_GA9411AA_AS   O22       NaN  No matching alignment
# 969  ESC_GA9414AA_AS   O44       NaN  No matching alignment
# 970  ESC_HA0144AA_AS  O120       NaN  No matching alignment
# 971  ESC_HA0237AA_AS  O145       NaN  No matching alignment
# 972  ESC_HA0900AA_AS  O145       NaN  No matching alignment
# 973  ESC_HA1970AA_AS   O25       NaN  No matching alignment
# 974  ESC_HA5975AA_AS   O36       NaN  No matching alignment
# 975  ESC_HA7906AA_AS   O10       NaN  No matching alignment
# 976  ESC_HA7922AA_AS   O36       NaN  No matching alignment
# 977  ESC_HA8065AA_AS    O1       NaN  No matching alignment
# 978  ESC_HA8079AA_AS   O49       NaN  No matching alignment
# 979  ESC_HA8383AA_AS  O172       NaN  No matching alignment
# 980  ESC_HA8443AA_AS   O26       NaN  No matching alignment
# 981  ESC_HA8509AA_AS    O5       NaN  No matching alignment
# 982  ESC_HA8699AA_AS   O10       NaN  No matching alignment
# 983  ESC_HA8733AA_AS  O145       NaN  No matching alignment
# 984  ESC_HA8762AA_AS   O36       NaN  No matching alignment
# 985  ESC_IA6411AA_AS  O145       NaN  No matching alignment
# 986  ESC_IA6426AA_AS  O145       NaN  No matching alignment
# 987  ESC_IA6978AA_AS  O145       NaN  No matching alignment
# 988  ESC_IA6985AA_AS  O145       NaN  No matching alignment
# 989  ESC_PA2018AA_AS  O157       NaN  No matching alignment
#
# [990 rows x 4 columns]
