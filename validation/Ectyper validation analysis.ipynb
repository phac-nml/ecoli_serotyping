# %%
import pandas as pd
import json

# %%
prediction_df = pd.read_json('new.json')

# %%
serotype_dict = json.load(open('serotype_dict.json'))

# %%
prediction_df
# Out:
#      H allele O allele          genome name predicted H predicted O
# 0      H10-21   O121-1  lcl|ESC_AA9715AA_AS         H10        O121
# 1       H11-4    O26-1  lcl|ESC_AA9722AA_AS         H11         O26
# 2       H11-4        -  lcl|ESC_AA9657AA_AS         H11           -
# 3       H11-4        -  lcl|ESC_AA9454AA_AS         H11           -
# 4       H11-4    O26-1  lcl|ESC_AA9419AA_AS         H11         O26
# 5       H11-4    O26-1  lcl|ESC_AA8012AA_AS         H11         O26
# 6       H11-4    O26-1  lcl|ESC_AA7929AA_AS         H11         O26
# 7       H15-3   O121-1  lcl|ESC_AA9661AA_AS         H15        O121
# 8      H19-24   O121-1  lcl|ESC_AA9366AA_AS         H19        O121
# 9      H19-24   O121-1  lcl|ESC_AA8510AA_AS         H19        O121
# 10       H2-2   O111-1  lcl|ESC_AA9052AA_AS          H2        O111
# 11       H2-2        -  lcl|ESC_AA8870AA_AS          H2           -
# 12       H2-2   O103-7  lcl|ESC_AA8380AA_AS          H2        O103
# 13       H2-8    O80-1  lcl|ESC_AA9307AA_AS          H2         O80
# 14     H21-12   O113-6  lcl|ESC_AA7966AA_AS         H21        O113
# 15      H25-2        -  lcl|ESC_AA8228AA_AS         H25           -
# 16     H25-12   O165-1  lcl|ESC_AA8769AA_AS         H25        O165
# 17      H28-3   O166-1  lcl|ESC_AA9692AA_AS         H28        O166
# 18       H6-4     O2-5  lcl|ESC_AA9535AA_AS          H6          O2
# 19      H6-13   O125-1  lcl|ESC_AA9695AA_AS          H6        O125
# 20       H7-1   O157-1  lcl|ESC_AA9724AA_AS          H7        O157
# 21       H7-1   O157-1  lcl|ESC_AA9720AA_AS          H7        O157
# 22       H7-1   O157-1  lcl|ESC_AA9696AA_AS          H7        O157
# 23       H7-1   O157-1  lcl|ESC_AA9679AA_AS          H7        O157
# 24       H7-1        -  lcl|ESC_AA9677AA_AS          H7           -
# 25       H7-1   O157-1  lcl|ESC_AA9650AA_AS          H7        O157
# 26       H7-1   O157-1  lcl|ESC_AA9634AA_AS          H7        O157
# 27       H7-1   O157-1  lcl|ESC_AA9592AA_AS          H7        O157
# 28       H7-1   O157-1  lcl|ESC_AA9581AA_AS          H7        O157
# 29       H7-1   O157-1  lcl|ESC_AA9568AA_AS          H7        O157
# ...       ...      ...                  ...         ...         ...
# 5762     H8-1   O111-2  lcl|ESC_OA0175AA_AS          H8        O111
# 5763     H8-2    O38-3  lcl|ESC_OA5487AA_AS          H8         O38
# 5764     H9-1    O9-12  lcl|ESC_OA5486AA_AS          H9          O9
# 5765     H9-1    O8-19  lcl|ESC_OA6341AA_AS          H9          O8
# 5766        -    O51-6  lcl|ESC_OA0180AA_AS           -         O51
# 5767   H10-17        -  lcl|ESC_PA2025AA_AS         H10           -
# 5768   H10-15    O91-2  lcl|ESC_PA1950AA_AS         H10         O91
# 5769    H18-2    O8-17  lcl|ESC_PA1940AA_AS         H18          O8
# 5770    H19-4        -  lcl|ESC_PA1946AA_AS         H19           -
# 5771    H19-2    O15-1  lcl|ESC_PA1945AA_AS         H19         O15
# 5772    H21-2    O8-37  lcl|ESC_PA1915AA_AS         H21          O8
# 5773    H23-1     O8-6  lcl|ESC_PA1999AA_AS         H23          O8
# 5774    H33-1     O1-1  lcl|ESC_PA1952AA_AS         H33          O1
# 5775    H38-7   O142-1  lcl|ESC_PA1953AA_AS         H38        O142
# 5776     H4-2        -  lcl|ESC_PA2037AA_AS          H4           -
# 5777     H4-2    O33-2  lcl|ESC_PA1951AA_AS          H4         O33
# 5778     H4-2     O5-1  lcl|ESC_PA1944AA_AS          H4          O5
# 5779    H42-1    O75-2  lcl|ESC_PA2007AA_AS         H42         O75
# 5780    H42-7    O10-1  lcl|ESC_PA1914AA_AS         H42         O10
# 5781    H43-1   O175-6  lcl|ESC_PA1918AA_AS         H43        O175
# 5782     H7-1   O157-1  lcl|ESC_PA2793AA_AS          H7        O157
# 5783     H7-1   O157-1  lcl|ESC_PA2614AA_AS          H7        O157
# 5784     H7-1   O157-1  lcl|ESC_PA2331AA_AS          H7        O157
# 5785     H7-1   O157-1  lcl|ESC_PA1949AA_AS          H7        O157
# 5786     H7-1   O157-1  lcl|ESC_PA1948AA_AS          H7        O157
# 5787     H7-1        -  lcl|ESC_PA1947AA_AS          H7           -
# 5788     H8-1     O8-1  lcl|ESC_PA1917AA_AS          H8          O8
# 5789     H8-2   O150-4  lcl|ESC_PA1943AA_AS          H8        O150
# 5790     H9-1    O8-19  lcl|ESC_PA2044AA_AS          H9          O8
# 5791     H9-5        -  lcl|ESC_PA1942AA_AS          H9           -
#
# [5792 rows x 5 columns]

# %%
new_list = []
for serotype, alleles in serotype_dict.items():
    for allele in alleles:
        new_entry = {
            'H source': allele.get('name'),
            'H allele': '-'.join([serotype, str(allele.get('num'))])
        }
        new_list.append(new_entry)
allele_df = pd.DataFrame(new_list)

# %%
# Merge with allele data
prediction_df = prediction_df.merge(allele_df, left_on='H allele', right_on='H allele', how='left')
allele_df.columns = ['O allele', 'O source']
prediction_df = prediction_df.merge(allele_df, left_on='O allele', right_on='O allele', how='left')
prediction_df
# Out:
#      H allele O allele          genome name predicted H predicted O  \
# 0      H10-21   O121-1  lcl|ESC_AA9715AA_AS         H10        O121
# 1       H11-4    O26-1  lcl|ESC_AA9722AA_AS         H11         O26
# 2       H11-4        -  lcl|ESC_AA9657AA_AS         H11           -
# 3       H11-4        -  lcl|ESC_AA9454AA_AS         H11           -
# 4       H11-4    O26-1  lcl|ESC_AA9419AA_AS         H11         O26
# 5       H11-4    O26-1  lcl|ESC_AA8012AA_AS         H11         O26
# 6       H11-4    O26-1  lcl|ESC_AA7929AA_AS         H11         O26
# 7       H15-3   O121-1  lcl|ESC_AA9661AA_AS         H15        O121
# 8      H19-24   O121-1  lcl|ESC_AA9366AA_AS         H19        O121
# 9      H19-24   O121-1  lcl|ESC_AA8510AA_AS         H19        O121
# 10       H2-2   O111-1  lcl|ESC_AA9052AA_AS          H2        O111
# 11       H2-2        -  lcl|ESC_AA8870AA_AS          H2           -
# 12       H2-2   O103-7  lcl|ESC_AA8380AA_AS          H2        O103
# 13       H2-8    O80-1  lcl|ESC_AA9307AA_AS          H2         O80
# 14     H21-12   O113-6  lcl|ESC_AA7966AA_AS         H21        O113
# 15      H25-2        -  lcl|ESC_AA8228AA_AS         H25           -
# 16     H25-12   O165-1  lcl|ESC_AA8769AA_AS         H25        O165
# 17      H28-3   O166-1  lcl|ESC_AA9692AA_AS         H28        O166
# 18       H6-4     O2-5  lcl|ESC_AA9535AA_AS          H6          O2
# 19      H6-13   O125-1  lcl|ESC_AA9695AA_AS          H6        O125
# 20       H7-1   O157-1  lcl|ESC_AA9724AA_AS          H7        O157
# 21       H7-1   O157-1  lcl|ESC_AA9720AA_AS          H7        O157
# 22       H7-1   O157-1  lcl|ESC_AA9696AA_AS          H7        O157
# 23       H7-1   O157-1  lcl|ESC_AA9679AA_AS          H7        O157
# 24       H7-1        -  lcl|ESC_AA9677AA_AS          H7           -
# 25       H7-1   O157-1  lcl|ESC_AA9650AA_AS          H7        O157
# 26       H7-1   O157-1  lcl|ESC_AA9634AA_AS          H7        O157
# 27       H7-1   O157-1  lcl|ESC_AA9592AA_AS          H7        O157
# 28       H7-1   O157-1  lcl|ESC_AA9581AA_AS          H7        O157
# 29       H7-1   O157-1  lcl|ESC_AA9568AA_AS          H7        O157
# ...       ...      ...                  ...         ...         ...
# 5762     H8-1   O111-2  lcl|ESC_OA0175AA_AS          H8        O111
# 5763     H8-2    O38-3  lcl|ESC_OA5487AA_AS          H8         O38
# 5764     H9-1    O9-12  lcl|ESC_OA5486AA_AS          H9          O9
# 5765     H9-1    O8-19  lcl|ESC_OA6341AA_AS          H9          O8
# 5766        -    O51-6  lcl|ESC_OA0180AA_AS           -         O51
# 5767   H10-17        -  lcl|ESC_PA2025AA_AS         H10           -
# 5768   H10-15    O91-2  lcl|ESC_PA1950AA_AS         H10         O91
# 5769    H18-2    O8-17  lcl|ESC_PA1940AA_AS         H18          O8
# 5770    H19-4        -  lcl|ESC_PA1946AA_AS         H19           -
# 5771    H19-2    O15-1  lcl|ESC_PA1945AA_AS         H19         O15
# 5772    H21-2    O8-37  lcl|ESC_PA1915AA_AS         H21          O8
# 5773    H23-1     O8-6  lcl|ESC_PA1999AA_AS         H23          O8
# 5774    H33-1     O1-1  lcl|ESC_PA1952AA_AS         H33          O1
# 5775    H38-7   O142-1  lcl|ESC_PA1953AA_AS         H38        O142
# 5776     H4-2        -  lcl|ESC_PA2037AA_AS          H4           -
# 5777     H4-2    O33-2  lcl|ESC_PA1951AA_AS          H4         O33
# 5778     H4-2     O5-1  lcl|ESC_PA1944AA_AS          H4          O5
# 5779    H42-1    O75-2  lcl|ESC_PA2007AA_AS         H42         O75
# 5780    H42-7    O10-1  lcl|ESC_PA1914AA_AS         H42         O10
# 5781    H43-1   O175-6  lcl|ESC_PA1918AA_AS         H43        O175
# 5782     H7-1   O157-1  lcl|ESC_PA2793AA_AS          H7        O157
# 5783     H7-1   O157-1  lcl|ESC_PA2614AA_AS          H7        O157
# 5784     H7-1   O157-1  lcl|ESC_PA2331AA_AS          H7        O157
# 5785     H7-1   O157-1  lcl|ESC_PA1949AA_AS          H7        O157
# 5786     H7-1   O157-1  lcl|ESC_PA1948AA_AS          H7        O157
# 5787     H7-1        -  lcl|ESC_PA1947AA_AS          H7           -
# 5788     H8-1     O8-1  lcl|ESC_PA1917AA_AS          H8          O8
# 5789     H8-2   O150-4  lcl|ESC_PA1943AA_AS          H8        O150
# 5790     H9-1    O8-19  lcl|ESC_PA2044AA_AS          H9          O8
# 5791     H9-5        -  lcl|ESC_PA1942AA_AS          H9           -
#
#                                             H source  \
# 0                            part_of_ESC_HA8316AA_AS
# 1                            part_of_ESC_KA5982AA_AS
# 2                            part_of_ESC_KA5982AA_AS
# 3                            part_of_ESC_KA5982AA_AS
# 4                            part_of_ESC_KA5982AA_AS
# 5                            part_of_ESC_KA5982AA_AS
# 6                            part_of_ESC_KA5982AA_AS
# 7                            part_of_ESC_HA8354AA_AS
# 8                            part_of_ESC_IA2145AA_AS
# 9                            part_of_ESC_IA2145AA_AS
# 10        1__fliC__fliC-H2__21 HQ116826;flagellin;H2
# 11        1__fliC__fliC-H2__21 HQ116826;flagellin;H2
# 12        1__fliC__fliC-H2__21 HQ116826;flagellin;H2
# 13                           part_of_ESC_IA1656AA_AS
# 14                           part_of_ESC_HA9063AA_AS
# 15                         fliC_311_AGSG01000116_H25
# 16                           part_of_ESC_LA1460AA_AS
# 17                           part_of_ESC_HA8147AA_AS
# 18                           part_of_ESC_GA6826AA_AS
# 19                           part_of_ESC_IA6434AA_AS
# 20      1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 21      1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 22      1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 23      1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 24      1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 25      1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 26      1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 27      1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 28      1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 29      1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ...                                              ...
# 5762    1__fliC__fliC-H8__74 AJ865465.1;flagellin;H8
# 5763    1__fliC__fliC-H8__75 AJ884569.1;flagellin;H8
# 5764    1__fliC__fliC-H9__76 AY249994.1;flagellin;H9
# 5765    1__fliC__fliC-H9__76 AY249994.1;flagellin;H9
# 5766                                             NaN
# 5767                         part_of_ESC_HA8818AA_AS
# 5768                         part_of_ESC_HA8450AA_AS
# 5769                         part_of_ESC_HA8741AA_AS
# 5770                         part_of_ESC_HA8562AA_AS
# 5771  1__fliC__fliC-H19__19 AY250002.1;flagellin;H19
# 5772                        fliC_84_AIHL01000060_H21
# 5773  1__fliC__fliC-H23__24 AY250005.1;flagellin;H23
# 5774  1__fliC__fliC-H33__34 AY250015.1;flagellin;H33
# 5775                         part_of_ESC_FA6870AA_AS
# 5776    1__fliC__fliC-H4__43 AJ605764.1;flagellin;H4
# 5777    1__fliC__fliC-H4__43 AJ605764.1;flagellin;H4
# 5778    1__fliC__fliC-H4__43 AJ605764.1;flagellin;H4
# 5779  1__fliC__fliC-H42__49 AY250021.1;flagellin;H42
# 5780                         part_of_ESC_LA1531AA_AS
# 5781  1__fliC__fliC-H43__50 AY250022.1;flagellin;H43
# 5782    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 5783    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 5784    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 5785    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 5786    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 5787    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# 5788    1__fliC__fliC-H8__74 AJ865465.1;flagellin;H8
# 5789    1__fliC__fliC-H8__75 AJ884569.1;flagellin;H8
# 5790    1__fliC__fliC-H9__76 AY249994.1;flagellin;H9
# 5791                         part_of_ESC_GA8879AA_AS
#
#                                                O source
# 0     8__wzx__wzx-O121__141 AY208937.1;O antigen fli...
# 1     8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# 2                                                   NaN
# 3                                                   NaN
# 4     8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# 5     8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# 6     8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# 7     8__wzx__wzx-O121__141 AY208937.1;O antigen fli...
# 8     8__wzx__wzx-O121__141 AY208937.1;O antigen fli...
# 9     8__wzx__wzx-O121__141 AY208937.1;O antigen fli...
# 10    8__wzx__wzx-O111__128 AF078736.1;O antigen fli...
# 11                                                  NaN
# 12                               wzx_194_NC:013353_O103
# 13    8__wzx__wzx-O80__298 AB812032.1;O antigen flip...
# 14                              part_of_ESC_GA3644AA_AS
# 15                                                  NaN
# 16    8__wzx__wzx-O165__198 GU068045.1;O antigen fli...
# 17    8__wzx__wzx-O166__199 GU299794.1;O antigen fli...
# 18                              part_of_ESC_IA0005AA_AS
# 19    8__wzx__wzx-O125__146 AB812053.1;O antigen fli...
# 20    8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# 21    8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# 22    8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# 23    8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# 24                                                  NaN
# 25    8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# 26    8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# 27    8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# 28    8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# 29    8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ...                                                 ...
# 5762  8__wzx__wzx-O111__129 AP010960;O antigen flipp...
# 5763                            part_of_ESC_GA9007AA_AS
# 5764                            part_of_ESC_GA8840AA_AS
# 5765                            part_of_ESC_JA1130AA_AS
# 5766                            part_of_ESC_FA6818AA_AS
# 5767                                                NaN
# 5768  9__wzy__wzy-O91__508 AY035396.1;O antigen poly...
# 5769                            part_of_ESC_GA9329AA_AS
# 5770                                                NaN
# 5771  8__wzx__wzx-O15__178 AY647261.1;O antigen flip...
# 5772                            part_of_ESC_PA1915AA_AS
# 5773  8__wzx__wzx-O8__297 AB811598.1;O antigen flipp...
# 5774  8__wzx__wzx-O1__112 GU299791.1;O antigen flipp...
# 5775  8__wzx__wzx-O142__168 AB812061.1;O antigen fli...
# 5776                                                NaN
# 5777  9__wzy__wzy-O33__444 AB811611.1;O antigen poly...
# 5778  8__wzx__wzx-O5__262 AB811596.1;O antigen flipp...
# 5779  9__wzy__wzy-O75__490 GU299795.1;O antigen poly...
# 5780  8__wzx__wzx-O10__113 AB811599.1;O antigen flip...
# 5781                            part_of_ESC_PA1918AA_AS
# 5782  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# 5783  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# 5784  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# 5785  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# 5786  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# 5787                                                NaN
# 5788  6__wzm__wzm-O8__90 AB010150.1;O-antigen ABC tr...
# 5789                            part_of_ESC_KA7444AA_AS
# 5790                            part_of_ESC_JA1130AA_AS
# 5791                                                NaN
#
# [5792 rows x 7 columns]

# %%
# Read ectyper output
# Data cleaning
prediction_df['genome name'] = prediction_df['genome name'].str.split('|', expand=True)[1]
prediction_df['predicted O'] = prediction_df['predicted O'].str.split('O', expand=True)[1]
prediction_df['predicted H'] = prediction_df['predicted H'].str.split('H', expand=True)[1]
prediction_df.index = prediction_df['genome name']
prediction_df = prediction_df[['predicted H','H source', 'predicted O', 'O source']]
prediction_df
# Out:
#                 predicted H                                        H source  \
# genome name
# ESC_AA9715AA_AS          10                         part_of_ESC_HA8316AA_AS
# ESC_AA9722AA_AS          11                         part_of_ESC_KA5982AA_AS
# ESC_AA9657AA_AS          11                         part_of_ESC_KA5982AA_AS
# ESC_AA9454AA_AS          11                         part_of_ESC_KA5982AA_AS
# ESC_AA9419AA_AS          11                         part_of_ESC_KA5982AA_AS
# ESC_AA8012AA_AS          11                         part_of_ESC_KA5982AA_AS
# ESC_AA7929AA_AS          11                         part_of_ESC_KA5982AA_AS
# ESC_AA9661AA_AS          15                         part_of_ESC_HA8354AA_AS
# ESC_AA9366AA_AS          19                         part_of_ESC_IA2145AA_AS
# ESC_AA8510AA_AS          19                         part_of_ESC_IA2145AA_AS
# ESC_AA9052AA_AS           2      1__fliC__fliC-H2__21 HQ116826;flagellin;H2
# ESC_AA8870AA_AS           2      1__fliC__fliC-H2__21 HQ116826;flagellin;H2
# ESC_AA8380AA_AS           2      1__fliC__fliC-H2__21 HQ116826;flagellin;H2
# ESC_AA9307AA_AS           2                         part_of_ESC_IA1656AA_AS
# ESC_AA7966AA_AS          21                         part_of_ESC_HA9063AA_AS
# ESC_AA8228AA_AS          25                       fliC_311_AGSG01000116_H25
# ESC_AA8769AA_AS          25                         part_of_ESC_LA1460AA_AS
# ESC_AA9692AA_AS          28                         part_of_ESC_HA8147AA_AS
# ESC_AA9535AA_AS           6                         part_of_ESC_GA6826AA_AS
# ESC_AA9695AA_AS           6                         part_of_ESC_IA6434AA_AS
# ESC_AA9724AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9720AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9696AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9679AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9677AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9650AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9634AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9592AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9581AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9568AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ...                     ...                                             ...
# ESC_OA0175AA_AS           8    1__fliC__fliC-H8__74 AJ865465.1;flagellin;H8
# ESC_OA5487AA_AS           8    1__fliC__fliC-H8__75 AJ884569.1;flagellin;H8
# ESC_OA5486AA_AS           9    1__fliC__fliC-H9__76 AY249994.1;flagellin;H9
# ESC_OA6341AA_AS           9    1__fliC__fliC-H9__76 AY249994.1;flagellin;H9
# ESC_OA0180AA_AS        None                                             NaN
# ESC_PA2025AA_AS          10                         part_of_ESC_HA8818AA_AS
# ESC_PA1950AA_AS          10                         part_of_ESC_HA8450AA_AS
# ESC_PA1940AA_AS          18                         part_of_ESC_HA8741AA_AS
# ESC_PA1946AA_AS          19                         part_of_ESC_HA8562AA_AS
# ESC_PA1945AA_AS          19  1__fliC__fliC-H19__19 AY250002.1;flagellin;H19
# ESC_PA1915AA_AS          21                        fliC_84_AIHL01000060_H21
# ESC_PA1999AA_AS          23  1__fliC__fliC-H23__24 AY250005.1;flagellin;H23
# ESC_PA1952AA_AS          33  1__fliC__fliC-H33__34 AY250015.1;flagellin;H33
# ESC_PA1953AA_AS          38                         part_of_ESC_FA6870AA_AS
# ESC_PA2037AA_AS           4    1__fliC__fliC-H4__43 AJ605764.1;flagellin;H4
# ESC_PA1951AA_AS           4    1__fliC__fliC-H4__43 AJ605764.1;flagellin;H4
# ESC_PA1944AA_AS           4    1__fliC__fliC-H4__43 AJ605764.1;flagellin;H4
# ESC_PA2007AA_AS          42  1__fliC__fliC-H42__49 AY250021.1;flagellin;H42
# ESC_PA1914AA_AS          42                         part_of_ESC_LA1531AA_AS
# ESC_PA1918AA_AS          43  1__fliC__fliC-H43__50 AY250022.1;flagellin;H43
# ESC_PA2793AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_PA2614AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_PA2331AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_PA1949AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_PA1948AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_PA1947AA_AS           7    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_PA1917AA_AS           8    1__fliC__fliC-H8__74 AJ865465.1;flagellin;H8
# ESC_PA1943AA_AS           8    1__fliC__fliC-H8__75 AJ884569.1;flagellin;H8
# ESC_PA2044AA_AS           9    1__fliC__fliC-H9__76 AY249994.1;flagellin;H9
# ESC_PA1942AA_AS           9                         part_of_ESC_GA8879AA_AS
#
#                 predicted O                                           O source
# genome name
# ESC_AA9715AA_AS         121  8__wzx__wzx-O121__141 AY208937.1;O antigen fli...
# ESC_AA9722AA_AS          26  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_AA9657AA_AS        None                                                NaN
# ESC_AA9454AA_AS        None                                                NaN
# ESC_AA9419AA_AS          26  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_AA8012AA_AS          26  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_AA7929AA_AS          26  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_AA9661AA_AS         121  8__wzx__wzx-O121__141 AY208937.1;O antigen fli...
# ESC_AA9366AA_AS         121  8__wzx__wzx-O121__141 AY208937.1;O antigen fli...
# ESC_AA8510AA_AS         121  8__wzx__wzx-O121__141 AY208937.1;O antigen fli...
# ESC_AA9052AA_AS         111  8__wzx__wzx-O111__128 AF078736.1;O antigen fli...
# ESC_AA8870AA_AS        None                                                NaN
# ESC_AA8380AA_AS         103                             wzx_194_NC:013353_O103
# ESC_AA9307AA_AS          80  8__wzx__wzx-O80__298 AB812032.1;O antigen flip...
# ESC_AA7966AA_AS         113                            part_of_ESC_GA3644AA_AS
# ESC_AA8228AA_AS        None                                                NaN
# ESC_AA8769AA_AS         165  8__wzx__wzx-O165__198 GU068045.1;O antigen fli...
# ESC_AA9692AA_AS         166  8__wzx__wzx-O166__199 GU299794.1;O antigen fli...
# ESC_AA9535AA_AS           2                            part_of_ESC_IA0005AA_AS
# ESC_AA9695AA_AS         125  8__wzx__wzx-O125__146 AB812053.1;O antigen fli...
# ESC_AA9724AA_AS         157  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9720AA_AS         157  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9696AA_AS         157  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9679AA_AS         157  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9677AA_AS        None                                                NaN
# ESC_AA9650AA_AS         157  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9634AA_AS         157  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9592AA_AS         157  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9581AA_AS         157  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9568AA_AS         157  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ...                     ...                                                ...
# ESC_OA0175AA_AS         111  8__wzx__wzx-O111__129 AP010960;O antigen flipp...
# ESC_OA5487AA_AS          38                            part_of_ESC_GA9007AA_AS
# ESC_OA5486AA_AS           9                            part_of_ESC_GA8840AA_AS
# ESC_OA6341AA_AS           8                            part_of_ESC_JA1130AA_AS
# ESC_OA0180AA_AS          51                            part_of_ESC_FA6818AA_AS
# ESC_PA2025AA_AS        None                                                NaN
# ESC_PA1950AA_AS          91  9__wzy__wzy-O91__508 AY035396.1;O antigen poly...
# ESC_PA1940AA_AS           8                            part_of_ESC_GA9329AA_AS
# ESC_PA1946AA_AS        None                                                NaN
# ESC_PA1945AA_AS          15  8__wzx__wzx-O15__178 AY647261.1;O antigen flip...
# ESC_PA1915AA_AS           8                            part_of_ESC_PA1915AA_AS
# ESC_PA1999AA_AS           8  8__wzx__wzx-O8__297 AB811598.1;O antigen flipp...
# ESC_PA1952AA_AS           1  8__wzx__wzx-O1__112 GU299791.1;O antigen flipp...
# ESC_PA1953AA_AS         142  8__wzx__wzx-O142__168 AB812061.1;O antigen fli...
# ESC_PA2037AA_AS        None                                                NaN
# ESC_PA1951AA_AS          33  9__wzy__wzy-O33__444 AB811611.1;O antigen poly...
# ESC_PA1944AA_AS           5  8__wzx__wzx-O5__262 AB811596.1;O antigen flipp...
# ESC_PA2007AA_AS          75  9__wzy__wzy-O75__490 GU299795.1;O antigen poly...
# ESC_PA1914AA_AS          10  8__wzx__wzx-O10__113 AB811599.1;O antigen flip...
# ESC_PA1918AA_AS         175                            part_of_ESC_PA1918AA_AS
# ESC_PA2793AA_AS         157  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_PA2614AA_AS         157  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_PA2331AA_AS         157  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_PA1949AA_AS         157  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_PA1948AA_AS         157  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_PA1947AA_AS        None                                                NaN
# ESC_PA1917AA_AS           8  6__wzm__wzm-O8__90 AB010150.1;O-antigen ABC tr...
# ESC_PA1943AA_AS         150                            part_of_ESC_KA7444AA_AS
# ESC_PA2044AA_AS           8                            part_of_ESC_JA1130AA_AS
# ESC_PA1942AA_AS        None                                                NaN
#
# [5792 rows x 4 columns]

# %%
# Get genome file paths as a list
import os
genome_dir = '/home/sam/Projects/MoreSerotype/temp/genomes'
genome_names = os.listdir(genome_dir)
genome_files = []
for genome_name in genome_names:
    file = os.path.join(genome_dir, genome_name)
    genome_files.append(file)

# Create serotype dataframe
from Bio import SeqIO
import re
serotype_data = []
for genome_file in genome_files:
    records = SeqIO.parse(genome_file, "fasta")
    entry = None
    for record in records:
        name = record.description
        genome_name = name.split('|')[0]
        serotype_tag = name.split('|')[1]
        serotypes = {'O': '','H': ''}
        for key in ['O','H']:
            regex = re.compile("(?<!(Non-))("+key+"\d{1,3})(?!\d)")
            results = regex.findall(serotype_tag)
            results_len = len(results)
            if results_len > 0:
                serotypes[key] = results[0][1][1:]
        entry = {
            'genome name': genome_name,
            'given O': serotypes['O'],
            'given H': serotypes['H'],
            'serotype tag': serotype_tag
        }
        if serotypes['O'] == '' and serotypes['H'] =='':
            pass
            # print(name)
        break
    if entry is not None:
        serotype_data.append(entry)

# %%
df2 = pd.DataFrame(serotype_data)
df2.index = df2['genome name']
df2 = df2[['given O', 'given H']]
df2.describe()
# Out:
#        given O given H
# count     5844    5844
# unique     193      56
# top        157
# freq      2315    2947

# %%
geneome_df = df2
# Merge two data frames
prediction_df = prediction_df.merge(geneome_df, left_index=True, right_index=True, how='inner')
prediction_df = prediction_df[['predicted O', 'given O', 'predicted H', 'given H', 'O source', 'H source']]
prediction_df
# Out:
#                 predicted O given O predicted H given H  \
# genome name
# ESC_AA9715AA_AS         121     157          10
# ESC_AA9722AA_AS          26      26          11
# ESC_AA9657AA_AS        None     103          11
# ESC_AA9454AA_AS        None      26          11
# ESC_AA9419AA_AS          26      26          11      11
# ESC_AA8012AA_AS          26     157          11
# ESC_AA7929AA_AS          26     157          11
# ESC_AA9661AA_AS         121     157          15
# ESC_AA9366AA_AS         121     121          19
# ESC_AA8510AA_AS         121     157          19
# ESC_AA9052AA_AS         111     111           2
# ESC_AA8870AA_AS        None     103           2
# ESC_AA8380AA_AS         103     157           2
# ESC_AA9307AA_AS          80     157           2
# ESC_AA7966AA_AS         113     113          21      21
# ESC_AA8228AA_AS        None     103          25
# ESC_AA8769AA_AS         165     157          25
# ESC_AA9692AA_AS         166     157          28
# ESC_AA9535AA_AS           2       2           6       6
# ESC_AA9695AA_AS         125     157           6
# ESC_AA9724AA_AS         157     157           7
# ESC_AA9720AA_AS         157     157           7
# ESC_AA9696AA_AS         157     157           7
# ESC_AA9679AA_AS         157     157           7
# ESC_AA9677AA_AS        None     157           7
# ESC_AA9650AA_AS         157     157           7
# ESC_AA9634AA_AS         157     157           7       7
# ESC_AA9592AA_AS         157     157           7
# ESC_AA9581AA_AS         157     157           7
# ESC_AA9568AA_AS         157     157           7
# ...                     ...     ...         ...     ...
# ESC_OA0175AA_AS         111     111           8
# ESC_OA5487AA_AS          38      38           8
# ESC_OA5486AA_AS           9       9           9
# ESC_OA6341AA_AS           8       8           9
# ESC_OA0180AA_AS          51      51        None
# ESC_PA2025AA_AS        None     157          10
# ESC_PA1950AA_AS          91      91          10
# ESC_PA1940AA_AS           8       8          18
# ESC_PA1946AA_AS        None     117          19
# ESC_PA1945AA_AS          15      15          19
# ESC_PA1915AA_AS           8       8          21
# ESC_PA1999AA_AS           8     157          23
# ESC_PA1952AA_AS           1       1          33
# ESC_PA1953AA_AS         142     142          38
# ESC_PA2037AA_AS        None     157           4
# ESC_PA1951AA_AS          33      33           4
# ESC_PA1944AA_AS           5       5           4
# ESC_PA2007AA_AS          75     157          42
# ESC_PA1914AA_AS          10      10          42
# ESC_PA1918AA_AS         175     175          43
# ESC_PA2793AA_AS         157     157           7
# ESC_PA2614AA_AS         157     157           7
# ESC_PA2331AA_AS         157     157           7
# ESC_PA1949AA_AS         157     157           7
# ESC_PA1948AA_AS         157     157           7
# ESC_PA1947AA_AS        None     157           7
# ESC_PA1917AA_AS           8      40           8
# ESC_PA1943AA_AS         150     150           8
# ESC_PA2044AA_AS           8     157           9
# ESC_PA1942AA_AS        None       3           9
#
#                                                           O source  \
# genome name
# ESC_AA9715AA_AS  8__wzx__wzx-O121__141 AY208937.1;O antigen fli...
# ESC_AA9722AA_AS  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_AA9657AA_AS                                                NaN
# ESC_AA9454AA_AS                                                NaN
# ESC_AA9419AA_AS  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_AA8012AA_AS  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_AA7929AA_AS  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_AA9661AA_AS  8__wzx__wzx-O121__141 AY208937.1;O antigen fli...
# ESC_AA9366AA_AS  8__wzx__wzx-O121__141 AY208937.1;O antigen fli...
# ESC_AA8510AA_AS  8__wzx__wzx-O121__141 AY208937.1;O antigen fli...
# ESC_AA9052AA_AS  8__wzx__wzx-O111__128 AF078736.1;O antigen fli...
# ESC_AA8870AA_AS                                                NaN
# ESC_AA8380AA_AS                             wzx_194_NC:013353_O103
# ESC_AA9307AA_AS  8__wzx__wzx-O80__298 AB812032.1;O antigen flip...
# ESC_AA7966AA_AS                            part_of_ESC_GA3644AA_AS
# ESC_AA8228AA_AS                                                NaN
# ESC_AA8769AA_AS  8__wzx__wzx-O165__198 GU068045.1;O antigen fli...
# ESC_AA9692AA_AS  8__wzx__wzx-O166__199 GU299794.1;O antigen fli...
# ESC_AA9535AA_AS                            part_of_ESC_IA0005AA_AS
# ESC_AA9695AA_AS  8__wzx__wzx-O125__146 AB812053.1;O antigen fli...
# ESC_AA9724AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9720AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9696AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9679AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9677AA_AS                                                NaN
# ESC_AA9650AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9634AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9592AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9581AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9568AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ...                                                            ...
# ESC_OA0175AA_AS  8__wzx__wzx-O111__129 AP010960;O antigen flipp...
# ESC_OA5487AA_AS                            part_of_ESC_GA9007AA_AS
# ESC_OA5486AA_AS                            part_of_ESC_GA8840AA_AS
# ESC_OA6341AA_AS                            part_of_ESC_JA1130AA_AS
# ESC_OA0180AA_AS                            part_of_ESC_FA6818AA_AS
# ESC_PA2025AA_AS                                                NaN
# ESC_PA1950AA_AS  9__wzy__wzy-O91__508 AY035396.1;O antigen poly...
# ESC_PA1940AA_AS                            part_of_ESC_GA9329AA_AS
# ESC_PA1946AA_AS                                                NaN
# ESC_PA1945AA_AS  8__wzx__wzx-O15__178 AY647261.1;O antigen flip...
# ESC_PA1915AA_AS                            part_of_ESC_PA1915AA_AS
# ESC_PA1999AA_AS  8__wzx__wzx-O8__297 AB811598.1;O antigen flipp...
# ESC_PA1952AA_AS  8__wzx__wzx-O1__112 GU299791.1;O antigen flipp...
# ESC_PA1953AA_AS  8__wzx__wzx-O142__168 AB812061.1;O antigen fli...
# ESC_PA2037AA_AS                                                NaN
# ESC_PA1951AA_AS  9__wzy__wzy-O33__444 AB811611.1;O antigen poly...
# ESC_PA1944AA_AS  8__wzx__wzx-O5__262 AB811596.1;O antigen flipp...
# ESC_PA2007AA_AS  9__wzy__wzy-O75__490 GU299795.1;O antigen poly...
# ESC_PA1914AA_AS  8__wzx__wzx-O10__113 AB811599.1;O antigen flip...
# ESC_PA1918AA_AS                            part_of_ESC_PA1918AA_AS
# ESC_PA2793AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_PA2614AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_PA2331AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_PA1949AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_PA1948AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_PA1947AA_AS                                                NaN
# ESC_PA1917AA_AS  6__wzm__wzm-O8__90 AB010150.1;O-antigen ABC tr...
# ESC_PA1943AA_AS                            part_of_ESC_KA7444AA_AS
# ESC_PA2044AA_AS                            part_of_ESC_JA1130AA_AS
# ESC_PA1942AA_AS                                                NaN
#
#                                                        H source
# genome name
# ESC_AA9715AA_AS                         part_of_ESC_HA8316AA_AS
# ESC_AA9722AA_AS                         part_of_ESC_KA5982AA_AS
# ESC_AA9657AA_AS                         part_of_ESC_KA5982AA_AS
# ESC_AA9454AA_AS                         part_of_ESC_KA5982AA_AS
# ESC_AA9419AA_AS                         part_of_ESC_KA5982AA_AS
# ESC_AA8012AA_AS                         part_of_ESC_KA5982AA_AS
# ESC_AA7929AA_AS                         part_of_ESC_KA5982AA_AS
# ESC_AA9661AA_AS                         part_of_ESC_HA8354AA_AS
# ESC_AA9366AA_AS                         part_of_ESC_IA2145AA_AS
# ESC_AA8510AA_AS                         part_of_ESC_IA2145AA_AS
# ESC_AA9052AA_AS      1__fliC__fliC-H2__21 HQ116826;flagellin;H2
# ESC_AA8870AA_AS      1__fliC__fliC-H2__21 HQ116826;flagellin;H2
# ESC_AA8380AA_AS      1__fliC__fliC-H2__21 HQ116826;flagellin;H2
# ESC_AA9307AA_AS                         part_of_ESC_IA1656AA_AS
# ESC_AA7966AA_AS                         part_of_ESC_HA9063AA_AS
# ESC_AA8228AA_AS                       fliC_311_AGSG01000116_H25
# ESC_AA8769AA_AS                         part_of_ESC_LA1460AA_AS
# ESC_AA9692AA_AS                         part_of_ESC_HA8147AA_AS
# ESC_AA9535AA_AS                         part_of_ESC_GA6826AA_AS
# ESC_AA9695AA_AS                         part_of_ESC_IA6434AA_AS
# ESC_AA9724AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9720AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9696AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9679AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9677AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9650AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9634AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9592AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9581AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9568AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ...                                                         ...
# ESC_OA0175AA_AS    1__fliC__fliC-H8__74 AJ865465.1;flagellin;H8
# ESC_OA5487AA_AS    1__fliC__fliC-H8__75 AJ884569.1;flagellin;H8
# ESC_OA5486AA_AS    1__fliC__fliC-H9__76 AY249994.1;flagellin;H9
# ESC_OA6341AA_AS    1__fliC__fliC-H9__76 AY249994.1;flagellin;H9
# ESC_OA0180AA_AS                                             NaN
# ESC_PA2025AA_AS                         part_of_ESC_HA8818AA_AS
# ESC_PA1950AA_AS                         part_of_ESC_HA8450AA_AS
# ESC_PA1940AA_AS                         part_of_ESC_HA8741AA_AS
# ESC_PA1946AA_AS                         part_of_ESC_HA8562AA_AS
# ESC_PA1945AA_AS  1__fliC__fliC-H19__19 AY250002.1;flagellin;H19
# ESC_PA1915AA_AS                        fliC_84_AIHL01000060_H21
# ESC_PA1999AA_AS  1__fliC__fliC-H23__24 AY250005.1;flagellin;H23
# ESC_PA1952AA_AS  1__fliC__fliC-H33__34 AY250015.1;flagellin;H33
# ESC_PA1953AA_AS                         part_of_ESC_FA6870AA_AS
# ESC_PA2037AA_AS    1__fliC__fliC-H4__43 AJ605764.1;flagellin;H4
# ESC_PA1951AA_AS    1__fliC__fliC-H4__43 AJ605764.1;flagellin;H4
# ESC_PA1944AA_AS    1__fliC__fliC-H4__43 AJ605764.1;flagellin;H4
# ESC_PA2007AA_AS  1__fliC__fliC-H42__49 AY250021.1;flagellin;H42
# ESC_PA1914AA_AS                         part_of_ESC_LA1531AA_AS
# ESC_PA1918AA_AS  1__fliC__fliC-H43__50 AY250022.1;flagellin;H43
# ESC_PA2793AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_PA2614AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_PA2331AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_PA1949AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_PA1948AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_PA1947AA_AS    1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_PA1917AA_AS    1__fliC__fliC-H8__74 AJ865465.1;flagellin;H8
# ESC_PA1943AA_AS    1__fliC__fliC-H8__75 AJ884569.1;flagellin;H8
# ESC_PA2044AA_AS    1__fliC__fliC-H9__76 AY249994.1;flagellin;H9
# ESC_PA1942AA_AS                         part_of_ESC_GA8879AA_AS
#
# [5792 rows x 6 columns]

# %%
# find conflict
'''
incorrect prediction if:
    given is different from predicton
    given is not None
    predicted is not None
'''
df1 = prediction_df
s1 = (df1['given O'].notnull() & df1['predicted O'].notnull()) & \
     (df1['given O']!=df1['predicted O'])
s2 = (df1['given H'].notnull() & df1['predicted H'].notnull()) & \
     (df1['given H']!=df1['predicted H'])
s3 = s1 | s2
incorrect_df = df1[s3]
print('%d incorrect predictions' %incorrect_df.shape[0])
print(incorrect_df.describe())
'''
no prediction if:
    both predicted antigen are None
'''
s1 = df1['predicted O'].isnull() & df1['predicted H'].isnull()
no_df = df1[s1]
print('%d no predictions' %no_df.shape[0])
print(no_df.describe())
'''
correct prediction if:
    for each given serotype, the correct prediction is made
'''
s1=df1['given O'].isnull() | (df1['given O']==df1['predicted O'])
s2=df1['given H'].isnull() | (df1['given H']==df1['predicted H'])
s3=s1&s2
correct_df = df1[s3]
# conflict rows
# match rows
print('%d correct predictions' %correct_df.shape[0])
print(correct_df.describe())
correct_df
# Out:
# 3400 incorrect predictions
#        predicted O given O predicted H given H  \
# count         2977    3400        3384    3400
# unique         157     185          46      56
# top            157     157           7
# freq          1169    1258        1290    2851
#
#                                                  O source  \
# count                                                2977
# unique                                                327
# top     8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# freq                                                 1148
#
#                                             H source
# count                                           3384
# unique                                           189
# top     1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# freq                                            1169
# 0 no predictions
#         predicted O  given O  predicted H  given H  O source  H source
# count             0        0            0        0         0         0
# unique            0        0            0        0         0         0
# 1892 correct predictions
#        predicted O given O predicted H given H  \
# count         1892    1892        1892    1892
# unique         131     131          47      47
# top            157     157           7       7
# freq           879     879         935     935
#
#                                                  O source  \
# count                                                1892
# unique                                                264
# top     8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# freq                                                  823
#
#                                             H source
# count                                           1892
# unique                                           220
# top     1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# freq                                             867
#                 predicted O given O predicted H given H  \
# genome name
# ESC_AA9419AA_AS          26      26          11      11
# ESC_AA7966AA_AS         113     113          21      21
# ESC_AA9535AA_AS           2       2           6       6
# ESC_AA9634AA_AS         157     157           7       7
# ESC_AA9463AA_AS         157     157           7       7
# ESC_AA9138AA_AS         157     157           7       7
# ESC_AA8918AA_AS         157     157           7       7
# ESC_AA8232AA_AS         157     157           7       7
# ESC_AA8101AA_AS         157     157           7       7
# ESC_BA0702AA_AS          26      26          11      11
# ESC_BA0620AA_AS          26      26          11      11
# ESC_AA9971AA_AS          26      26          11      11
# ESC_BA1659AA_AS         157     157           7       7
# ESC_BA1334AA_AS         157     157           7       7
# ESC_BA1121AA_AS         157     157           7       7
# ESC_BA0988AA_AS         157     157           7       7
# ESC_BA0981AA_AS         157     157           7       7
# ESC_BA0935AA_AS         157     157           7       7
# ESC_BA0652AA_AS         157     157           7       7
# ESC_BA0304AA_AS         157     157           7       7
# ESC_BA0235AA_AS         157     157           7       7
# ESC_BA0143AA_AS         157     157           7       7
# ESC_BA3534AA_AS          26      26          11      11
# ESC_BA3176AA_AS          26      26          11      11
# ESC_BA2923AA_AS          26      26          11      11
# ESC_BA2773AA_AS          26      26          11      11
# ESC_BA2284AA_AS           2       2           6       6
# ESC_BA3707AA_AS           2       2           6       6
# ESC_BA3699AA_AS         157     157           7       7
# ESC_BA3688AA_AS         157     157           7       7
# ...                     ...     ...         ...     ...
# ESC_NA9490AA_AS         157     157           7       7
# ESC_NA9489AA_AS         157     157           7       7
# ESC_NA9487AA_AS         157     157           7       7
# ESC_NA9486AA_AS         157     157           7       7
# ESC_NA9479AA_AS         157     157           7       7
# ESC_NA9477AA_AS         157     157           7       7
# ESC_NA9476AA_AS         157     157           7       7
# ESC_NA9473AA_AS         157     157           7       7
# ESC_NA9468AA_AS         157     157           7       7
# ESC_NA9467AA_AS         157     157           7       7
# ESC_NA9464AA_AS         157     157           7       7
# ESC_NA9462AA_AS         157     157           7       7
# ESC_NA9450AA_AS         157     157           7       7
# ESC_NA9449AA_AS         157     157           7       7
# ESC_NA9441AA_AS         157     157           7       7
# ESC_NA9440AA_AS         157     157           7       7
# ESC_NA9439AA_AS         157     157           7       7
# ESC_NA9455AA_AS         157     157           7       7
# ESC_OA7580AA_AS         104     104           4       4
# ESC_OA7579AA_AS         104     104           4       4
# ESC_OA7577AA_AS         104     104           4       4
# ESC_PA1909AA_AS         157     157           7       7
# ESC_OA7578AA_AS         157     157           7       7
# ESC_OA7576AA_AS         157     157           7       7
# ESC_OA5503AA_AS         157     157           7       7
# ESC_OA5500AA_AS         157     157           7       7
# ESC_OA0198AA_AS         157     157           7       7
# ESC_OA0191AA_AS         157     157           7       7
# ESC_OA0123AA_AS         157     157           7       7
# ESC_OA0118AA_AS         157     157           7       7
#
#                                                           O source  \
# genome name
# ESC_AA9419AA_AS  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_AA7966AA_AS                            part_of_ESC_GA3644AA_AS
# ESC_AA9535AA_AS                            part_of_ESC_IA0005AA_AS
# ESC_AA9634AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9463AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA9138AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA8918AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA8232AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_AA8101AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_BA0702AA_AS  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_BA0620AA_AS  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_AA9971AA_AS  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_BA1659AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_BA1334AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_BA1121AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_BA0988AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_BA0981AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_BA0935AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_BA0652AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_BA0304AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_BA0235AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_BA0143AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_BA3534AA_AS  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_BA3176AA_AS  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_BA2923AA_AS  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_BA2773AA_AS  8__wzx__wzx-O26__234 AF529080.1;O antigen flip...
# ESC_BA2284AA_AS                            part_of_ESC_IA0005AA_AS
# ESC_BA3707AA_AS                            part_of_ESC_IA0005AA_AS
# ESC_BA3699AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_BA3688AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ...                                                            ...
# ESC_NA9490AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9489AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9487AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9486AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9479AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9477AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9476AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9473AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9468AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9467AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9464AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9462AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9450AA_AS                            part_of_ESC_HA6276AA_AS
# ESC_NA9449AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9441AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9440AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9439AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_NA9455AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_OA7580AA_AS                            part_of_ESC_HA7426AA_AS
# ESC_OA7579AA_AS                            part_of_ESC_HA7426AA_AS
# ESC_OA7577AA_AS                            part_of_ESC_HA7426AA_AS
# ESC_PA1909AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_OA7578AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_OA7576AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_OA5503AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_OA5500AA_AS                              wzy_201_JH953200_O157
# ESC_OA0198AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_OA0191AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_OA0123AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
# ESC_OA0118AA_AS  8__wzx__wzx-O157__185 AF061251.1;O antigen fli...
#
#                                                      H source
# genome name
# ESC_AA9419AA_AS                       part_of_ESC_KA5982AA_AS
# ESC_AA7966AA_AS                       part_of_ESC_HA9063AA_AS
# ESC_AA9535AA_AS                       part_of_ESC_GA6826AA_AS
# ESC_AA9634AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9463AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA9138AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA8918AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA8232AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_AA8101AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_BA0702AA_AS                       part_of_ESC_KA5982AA_AS
# ESC_BA0620AA_AS                       part_of_ESC_KA5982AA_AS
# ESC_AA9971AA_AS                       part_of_ESC_KA5982AA_AS
# ESC_BA1659AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_BA1334AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_BA1121AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_BA0988AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_BA0981AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_BA0935AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_BA0652AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_BA0304AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_BA0235AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_BA0143AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_BA3534AA_AS                       part_of_ESC_KA5982AA_AS
# ESC_BA3176AA_AS                       part_of_ESC_KA5982AA_AS
# ESC_BA2923AA_AS                       part_of_ESC_KA5982AA_AS
# ESC_BA2773AA_AS                       part_of_ESC_KA5982AA_AS
# ESC_BA2284AA_AS                       part_of_ESC_GA6826AA_AS
# ESC_BA3707AA_AS                       part_of_ESC_BA3707AA_AS
# ESC_BA3699AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_BA3688AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ...                                                       ...
# ESC_NA9490AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9489AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9487AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9486AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9479AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9477AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9476AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9473AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9468AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9467AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9464AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9462AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9450AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9449AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9441AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9440AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9439AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_NA9455AA_AS                       part_of_ESC_NA9455AA_AS
# ESC_OA7580AA_AS  1__fliC__fliC-H4__43 AJ605764.1;flagellin;H4
# ESC_OA7579AA_AS  1__fliC__fliC-H4__43 AJ605764.1;flagellin;H4
# ESC_OA7577AA_AS  1__fliC__fliC-H4__43 AJ605764.1;flagellin;H4
# ESC_PA1909AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_OA7578AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_OA7576AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_OA5503AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_OA5500AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_OA0198AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_OA0191AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_OA0123AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
# ESC_OA0118AA_AS  1__fliC__fliC-H7__64 AF228487.1;flagellin;H7
#
# [1892 rows x 6 columns]
